# %%
#Class 4 ex3
# How many functions are in this code? Where are the functions called?
# Which functions are value returning and where are the values returned?

def main():
    ###will get variables to pass through functions as arguements
    goal = float(input("Enter total retirement savings goal: "))
    pmt=float(input("Enter the yearly savings budget: "))
    years = int(input("Enter number of years until retirement: "))
    rate = float(input("Enter interest rate: "))/100
    FVA = FVAnnuity(pmt,years,rate)
    PMTG = Save(goal,years,rate)
    print("\n\nSaving ${0:,.0f} per year, in {1:,.0f} years, you will have saved ${2:,.2f} ".format(pmt,years,FVA))
    print("\nIn order to save ${0:,.0f} within {1:,.0f} years you would need to save ${2:,.02f} each year".format(goal,years,PMTG))

###funtion 1 value of nest egg as inputed    
def FVAnnuity(p,t,r):
    FV = p*(((1+r)**t-1)/r)
    return FV

###function 2 amount saved to meet goal
def Save(g,t,r):
    P= g/(((1+r)**t-1)/r)
    return P
   

main()

# %%
#demo of importing a module
#call function with modulename.functionname as {optional nickname)

import random
number = random.random()
print(number)

#often we import the function with an abbreviated name (as)
import random
number = random.random()
print(number)

# %%
###EX1 Shell
###Main
def main():
    ###will get variables to pass through functions as arguements
    val=float(input("Enter value of home: "))
    bal = int(input("Enter balance on current mortgage: "))
     
##function 
def loan(v,b):

# %%
#Ex 2 Shell Add Function to Return Number of Years to Reach Goal at an Amt
import math 

def main():
    ###will get variables to pass through functions as arguements
    goal = float(input("Enter total retirement savings goal: "))
    pmt=float(input("Enter the yearly savings budget: "))
    years = int(input("Enter number of years until retirement: "))
    rate = float(input("Enter interest rate: "))/100
    FVA = FVAnnuity(pmt,years,rate)
    PMTG = Save(goal,years,rate)
    
    print("\n\nSaving ${0:,.0f} per year, in {1:,.0f} years, you will have saved ${2:,.2f} ".format(pmt,years,FVA))
    print("\nIn order to save ${0:,.0f} within {1:,.0f} years, you would need to save ${2:,.02f} each year".format(goal,years,PMTG))
    print("\nSaving ${0:,.0f} per year, it will take {1:,.0f} years to save ${2:,.0f} ".format())
###funtion 1 value of nest egg as inputed    
def FVAnnuity(p,t,r):
    FV = p*(((1+r)**t-1)/r)
    return FV

###function 2 amount saved to meet goal
def Save(g,t,r):
    P= g/(((1+r)**t-1)/r)
    return P

###function 3 time needed to meet goal at pmt amount

main()

# %%
###Class 5 Demo1 and 1.1
###Demo 1 & 1.1    
import matplotlib.pyplot as plt
import random as rnd

###Set up Random Number
IBM_pr = rnd.randint(125,200)
MSFT_pr = rnd.randint(325,500)
ORCL_pr = rnd.randint(100,175)

IBM_sh = int(input("Enter the number of IBM Shares: "))
MSFT_sh = int(input("Enter the number of MSFT Shares: "))
ORCL_sh = int(input("Enter the number of ORCL Shares: "))

IBM_vl = IBM_pr*IBM_sh
MSFT_vl = MSFT_pr*MSFT_sh
ORCL_vl = ORCL_pr*ORCL_sh
TOT= IBM_vl+MSFT_vl + ORCL_vl

print("\n\nYour total portfolio is worth $",format(TOT,',d'), sep="")
print("\nYour IBM portfolio is worth $",format(IBM_vl,',d'), sep="")     
print("Your ORCL portfolio is worth $",format(ORCL_vl,',d'), sep="")  
print("Your MSFT portfolio is worth $",format(MSFT_vl,',d'), sep="")  

y = [IBM_vl,MSFT_vl,ORCL_vl]
x = ["IBM","MSFT","ORCL"]
bar_width = .5
plot=plt.bar(x,y,bar_width, color= ('b','g','orange'))
plt.title('Portfolio Value')
plt.xlabel('Stock')
plt.ylabel('Holding Value')

# %%
### Class 5Ex3 Shell
###Initialize Variables
cpay=3
tpay=7.5
npay=8.5
wpay=10
cprob=.25
tprob=.12
nprob=.11
wprob=.09

###Gather User Input
CL=float(input("Enter the amount to wager on the Celtics to win the NBA Championship: "))
TH=float(input("Enter the amount to wager on the Thunder to win the NBA Championship: "))
NG=float(input("Enter the amount to wager on the Nuggets to win the NBA Championship: "))
WL=float(input("Enter the amount to wager on the Wolves to win the NBA Championship: "))
x=int(input("Enter the number of simulations you wish to run: "))  


####Write Simulation Here
###1) Set up accumulator variables
###2) Set up count-countrolled loop - generate random number
###3) Evaluate random number against win probabilities and assign wins to the approptiate team

###outside of loop calcuate payout (simpay =)
###payout will be sum of each team's payoff*amount wagered*number of wins

###output
print("\n\nIn your simulation:")
print("\nThe Celtics won {0:1,d} times.".format(c))
print("The Thunder won {0:1,d} times.".format(t))
print("The Nuggets won {0:1,d} times.".format(n))
print("The Wolves won {0:1,d} times.".format(w))
print("\n\nYour average simulated winings are: $",format(simpay,',.0f'),sep="")
